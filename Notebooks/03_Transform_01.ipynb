# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/brain-ct-hemorrhage-segmentation/blob/main/Notebooks/Transform_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Google.Drive Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Unzipping

# %%
import os

zip_file_path = '/content/drive/MyDrive/brain_ct_project/processed_data_full.zip'
output_dir = '/content/brain_ct_project_data'

os.makedirs(output_dir, exist_ok=True)

# !unzip -q {zip_file_path} -d {output_dir}

print(f"File unzipped to {output_dir}")
# Out:
# File unzipped to /content/brain_ct_project_data

# %% [markdown]
# #Transforming

# %% [markdown]
# ##Train

# %%
split = "train"

# %%
import os
import numpy as np
import pandas as pd

base_path = "/content/brain_ct_project_data"

mask_dir = os.path.join(base_path, split, "masks")

data = []

for mask_name in sorted(os.listdir(mask_dir)):

    if not mask_name.endswith(".npy"):
        continue

    mask_path = os.path.join(mask_dir, mask_name)

    try:
        mask = np.load(mask_path)
    except:
        print(f"Skipping unreadable: {mask_name}")
        continue

    # binary label
    label = 1 if np.any(mask > 0) else 0

    data.append([mask_name, label])

df = pd.DataFrame(data, columns=["filename", "label"])

csv_path = os.path.join(base_path, split, "label_train.csv")
df.to_csv(csv_path, index=False)

print("Saved:", csv_path)
print(df["label"].value_counts())
# Out:
# Saved: /content/brain_ct_project_data/train/label_train.csv
# label
# 0    2033
# 1     248
# Name: count, dtype: int64

# %% [markdown]
# ##Validation

# %%
split = "val"

# %%
import os
import numpy as np
import pandas as pd

base_path = "/content/brain_ct_project_data"

mask_dir = os.path.join(base_path, split, "masks")

data = []

for mask_name in sorted(os.listdir(mask_dir)):

    if not mask_name.endswith(".npy"):
        continue

    mask_path = os.path.join(mask_dir, mask_name)

    try:
        mask = np.load(mask_path)
    except:
        print(f"Skipping unreadable: {mask_name}")
        continue

    # binary label
    label = 1 if np.any(mask > 0) else 0

    data.append([mask_name, label])

df = pd.DataFrame(data, columns=["filename", "label"])

csv_path = os.path.join(base_path, split, "label_val.csv")
df.to_csv(csv_path, index=False)

print("Saved:", csv_path)
print(df["label"].value_counts())
# Out:
# Saved: /content/brain_ct_project_data/val/label_val.csv
# label
# 0    208
# 1     33
# Name: count, dtype: int64

# %% [markdown]
# ##Test

# %%
split = "test"

# %%
import os
import numpy as np
import pandas as pd

base_path = "/content/brain_ct_project_data"

mask_dir = os.path.join(base_path, split, "masks")

data = []

for mask_name in sorted(os.listdir(mask_dir)):

    if not mask_name.endswith(".npy"):
        continue

    mask_path = os.path.join(mask_dir, mask_name)

    try:
        mask = np.load(mask_path)
    except:
        print(f"Skipping unreadable: {mask_name}")
        continue

    # binary label
    label = 1 if np.any(mask > 0) else 0

    data.append([mask_name, label])

df = pd.DataFrame(data, columns=["filename", "label"])

csv_path = os.path.join(base_path, split, "label_test.csv")
df.to_csv(csv_path, index=False)

print("Saved:", csv_path)
print(df["label"].value_counts())
# Out:
# Saved: /content/brain_ct_project_data/test/label_test.csv
# label
# 0    255
# 1     37
# Name: count, dtype: int64

# %% [markdown]
# #Saving

# %%
import shutil
import os

base_path = "/content/brain_ct_project_data"
drive_path = "/content/drive/MyDrive/brain_ct_project"

os.makedirs(drive_path, exist_ok=True)

# %%
# source files
train_label = os.path.join(base_path, "train", "label_train.csv")
val_label   = os.path.join(base_path, "val", "label_val.csv")
test_label  = os.path.join(base_path, "test", "label_test.csv")

# destination
shutil.copy(train_label, os.path.join(drive_path, "label_train.csv"))
shutil.copy(val_label,   os.path.join(drive_path, "label_val.csv"))
shutil.copy(test_label,  os.path.join(drive_path, "label_test.csv"))

print("✅ Labels copied to Google Drive")
# Out:
# ✅ Labels copied to Google Drive

# %%
print(os.listdir(drive_path))
# Out:
# ['splits', 'processed_data_full.zip', 'label_train.csv', 'label_val.csv', 'label_test.csv']
