# %% [markdown]
# <a href="https://colab.research.google.com/github/FaridRash/brain-ct-hemorrhage-segmentation/blob/main/Notebooks/05_Windowing_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mounting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Unzipping

# %%
import os

zip_file_path = '/content/drive/MyDrive/brain_ct_project/air_filtered_data.zip'
output_dir = '/content/brain_ct_project' # Unzip to the specified directory

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Construct the unzip command
unzip_command = f'unzip -q "{zip_file_path}" -d "{output_dir}"'

print(f"Executing: {unzip_command}")
os.system(unzip_command)
print("Unzipping complete.")
# Out:
# Executing: unzip -q "/content/drive/MyDrive/brain_ct_project/air_filtered_data.zip" -d "/content/brain_ct_project"
# Unzipping complete.

# %% [markdown]
# #Windowing

# %%
import os
import numpy as np

# %% [markdown]
# ##Train set windowing

# %%
# paths
input_dir = "/content/brain_ct_project/train/images"
output_dir = "/content/brain_ct_project/train/images_windowed"

os.makedirs(output_dir, exist_ok=True)

# window params
WL = 40
WW = 80

lower = WL - (WW / 2)
upper = WL + (WW / 2)

print("Processing Train...")

count = 0

for file in sorted(os.listdir(input_dir)):

    if not file.endswith(".npy"):
        continue

    path = os.path.join(input_dir, file)

    try:
        img = np.load(path).astype(np.float32)
    except:
        print("Skipping:", file)
        continue

    # ---- windowing ----
    img = np.clip(img, lower, upper)

    # ---- normalize to 0–1 ----
    img = (img - lower) / (upper - lower)

    # ---- save ----
    np.save(os.path.join(output_dir, file), img)

    count += 1

print("Train done:", count)
# Out:
# Processing Train...
# Train done: 2116

# %% [markdown]
# ##Validation set windowing

# %%
# paths
input_dir = "/content/brain_ct_project/val/images"
output_dir = "/content/brain_ct_project/val/images_windowed"

os.makedirs(output_dir, exist_ok=True)

# window params
WL = 40
WW = 80

lower = WL - (WW / 2)
upper = WL + (WW / 2)

print("Processing Validation...")

count = 0

for file in sorted(os.listdir(input_dir)):

    if not file.endswith(".npy"):
        continue

    path = os.path.join(input_dir, file)

    try:
        img = np.load(path).astype(np.float32)
    except:
        print("Skipping:", file)
        continue

    # ---- windowing ----
    img = np.clip(img, lower, upper)

    # ---- normalize to 0–1 ----
    img = (img - lower) / (upper - lower)

    # ---- save ----
    np.save(os.path.join(output_dir, file), img)

    count += 1

print("Validation done:", count)
# Out:
# Processing Validation...
# Validation done: 224

# %% [markdown]
# ##Test set windowing

# %%
# paths
input_dir = "/content/brain_ct_project/test/images"
output_dir = "/content/brain_ct_project/test/images_windowed"

os.makedirs(output_dir, exist_ok=True)

# window params
WL = 40
WW = 80

lower = WL - (WW / 2)
upper = WL + (WW / 2)

print("Processing Test...")

count = 0

for file in sorted(os.listdir(input_dir)):

    if not file.endswith(".npy"):
        continue

    path = os.path.join(input_dir, file)

    try:
        img = np.load(path).astype(np.float32)
    except:
        print("Skipping:", file)
        continue

    # ---- windowing ----
    img = np.clip(img, lower, upper)

    # ---- normalize to 0–1 ----
    img = (img - lower) / (upper - lower)

    # ---- save ----
    np.save(os.path.join(output_dir, file), img)

    count += 1

print("Test done:", count)
# Out:
# Processing Test...
# Test done: 274
